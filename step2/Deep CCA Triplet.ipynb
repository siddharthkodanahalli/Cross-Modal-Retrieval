# %%
import pandas as pd
import pickle
import numpy as np
import tensorflow.keras as keras
from tensorflow.keras import backend as K
from tqdm import tqdm
import tensorflow as tf
import random
import os
from pathlib import Path
from tqdm import tqdm

# %%
def get_average_embeddings(path):
    with open(path,'rb') as f:
        view_data = pickle.load(f)
        
    view1 = view_data[0]
    view2 = view_data[1]
    ids = view_data[2]
    
    return (view1, view2, ids)
    

def get_other_embeddings(path_view1, path_view2):
    with open(path_view1,'rb') as f:
        view1_data = pickle.load(f)
    
    ids = view1_data[2]
    
    with open(path_view2, 'rb') as f:
        view2_data = pickle.load(f)
    
    return view1_data[0], view2_data[0], ids
        

def map_classes(ids_to_keep):
    
    with open('/common/home/aj780/machine_learning/CCA Data/classes1M.pkl','rb') as f:
        
        id2classes = pickle.load(f)
    
    
    id2classes = {k:v for k,v in id2classes.items() if k in ids_to_keep}
    
    classes2id = {}
    for id_, class_ in id2classes.items():
    
        if class_ in classes2id:
            classes2id[class_].append(id_)
        else:
            classes2id[class_] = [id_]
        
    all_classes = list(classes2id.keys())
    
    return id2classes, classes2id, all_classes

# %%
def triplet_pairs(embeds_view1, embeds_view2, id2classes, classes2id, all_classes):
    
    anchors = []
    positives = []
    negatives = []
    for id_, anchor in embeds_view1.items():
        class_id = id2classes[id_]
#         positive_id = random.sample(classes2id[class_id], 1)
        
        all_classes.remove(class_id)
        negative_class = random.sample(all_classes, 1)[0]
        all_classes.append(class_id)
        negative_id = random.sample(classes2id[negative_class], 1)[0]
        
        anchors.append(anchor)
        positives.append(embeds_view2[id_])
        negatives.append(embeds_view2[negative_id])
        #apn.append([anchor, embeds_view2[id_], embeds_view2[negative_id]])
    
    return np.array(anchors), np.array(positives), np.array(negatives)

# %%
def get_data(view1_path, view2_path):
    if view2_path is None:
        image_temp_data, text_temp_data, ids = get_average_embeddings(view1_path)
    else:
        image_temp_data, text_temp_data, ids = get_other_embeddings(view1_path, view2_path)

    id2classes, classes2id, all_classes = map_classes(set(ids))



    ## creating dictionary of ids to embeddings

    embeds_view1 = {}
    for id_, embed in zip(ids, image_temp_data):
        embeds_view1[id_] = embed

    embeds_view2 = {}
    for id_, embed in zip(ids, text_temp_data):
        embeds_view2[id_] = embed

    image_train_data, text_train_data, text_train_negatives = triplet_pairs(embeds_view1, embeds_view2,id2classes, classes2id, all_classes)
    
    return ids, image_train_data, text_train_data, text_train_negatives

# %%
def triplet_cca_loss(latent_size, eps):
    def inner_triplet_cca_loss(y_true, y_pred):
        
        ## getting shared embeddings of all 3 pairs
        

        anchor_embeddings = y_pred[:,0:latent_size]
        positive_embeddings = y_pred[:,latent_size:2*latent_size]
        negative_embeddings = y_pred[:,2*latent_size: 3*latent_size]
        
        positive_dist = K.sum(K.square(anchor_embeddings - positive_embeddings), axis=1)
        negative_dist = K.sum(K.square(anchor_embeddings - negative_embeddings), axis=1)
        return K.maximum(positive_dist - negative_dist + eps, 0.)
    return inner_triplet_cca_loss

# %%
def get_base_model(layer_sizes, reg_lambda):
    model = keras.models.Sequential()
    for id_, i in enumerate(layer_sizes):
        if id_ == len(layer_sizes)-1:
            activation = 'linear'
        else:
            activation = 'relu'
        model.add(keras.layers.Dense(i, activation=activation, kernel_regularizer=keras.regularizers.l2(reg_lambda)))
    
    return model

def get_model(layer_sizes, input_size1, input_size2, input_size3, reg_lambda):
    view1_input = keras.layers.Input(shape=(input_size1,))
    view2_input = keras.layers.Input(shape=(input_size2,))
    view3_input = keras.layers.Input(shape=(input_size3,))
    
    base_model = get_base_model(layer_sizes, reg_lambda)
    
    view1 = base_model(view1_input)
    view2 = base_model(view2_input)
    view3 = base_model(view3_input)
    


    merged = keras.layers.Concatenate()([view1, view2, view3])
    model = keras.Model(inputs=[view1_input, view2_input, view3_input], outputs=merged)

    return model

def train_model(output_dir, view1_train_data, view2_train_data, view3_train_data, view1_val_data, view2_val_data, view3_val_data,
                layer_sizes, latent_size, input_size1, input_size2, input_size3, learning_rate, margin, epochs, batch_size, reg_lambda):
    
    
    model = get_model(layer_sizes, input_size1, input_size2, input_size3, reg_lambda)
    sgd = keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9, nesterov=True)
    model.compile(loss=triplet_cca_loss(latent_size, margin), optimizer=sgd)
    
    checkpointer = keras.callbacks.ModelCheckpoint(filepath=output_dir +"/"+ 'model.h5', save_best_only=True, save_weights_only=False)
    
    model.fit(x=[view1_train_data, view2_train_data, view3_train_data],y=np.zeros(len(view1_train_data)), 
              validation_data = ([view1_val_data,view2_val_data,view3_val_data],np.zeros(len(view1_val_data))),
              epochs=epochs, batch_size=batch_size, callbacks = [checkpointer])
    
    return model

# %%
def predict_model(model, view1_test_data, view2_test_data, view3_test_negatives):
    preds = model.predict([view1_test_data, view2_test_data, view3_test_negatives])
    
    img_l = int(preds.shape[1] / 3)
    text_l = 2*int(preds.shape[1] / 3)

    image_embeds = preds[:,0:img_l]
    text_embeds = preds[:,img_l:text_l]
    
    return (image_embeds, text_embeds)

# %%
def evaluation(data_X, data_Y, data_ids, im2recipe, samples_to_draw, time_sample=10):
    idxs = np.argsort(data_ids)
    names = data_ids[idxs]
    image_vecs = data_X[idxs]
    text_vecs = data_Y[idxs]
    idxs = range(samples_to_draw)
    
    glob_rank = []
    glob_recall = {1:0.0,5:0.0,10:0.0}
    for i in range(time_sample):
        ids = random.sample(range(0,len(names)), samples_to_draw)
        im_sub = image_vecs[ids,:]
        instr_sub = text_vecs[ids,:]
        ids_sub = names[ids]

        if im2recipe:
            sims = np.dot(im_sub,instr_sub.T) # for im2recipe
        else:
            sims = np.dot(instr_sub,im_sub.T) # for recipe2im

        med_rank = []
        recall = {1:0.0,5:0.0,10:0.0}
        for ii in idxs:
            name = ids_sub[ii]
            # get a column of similarities
            sim = sims[ii,:]

            # sort indices in descending order
            sorting = np.argsort(sim)[::-1].tolist()

            # find where the index of the pair sample ended up in the sorting
            pos = sorting.index(ii)

            if (pos+1) == 1:
                recall[1]+=1
            if (pos+1) <=5:
                recall[5]+=1
            if (pos+1)<=10:
                recall[10]+=1

            # store the position
            med_rank.append(pos+1)

        for i in recall.keys():
            recall[i]=recall[i]/samples_to_draw

        med = np.median(med_rank)

        for i in recall.keys():
            glob_recall[i]+=recall[i]
        glob_rank.append(med)

    for i in glob_recall.keys():
        glob_recall[i] = glob_recall[i]/time_sample

    return np.average(glob_rank), glob_recall

# %% [markdown]
# ### Running models on average embeddings

# %%
train_ids, image_train_data, text_train_data, text_train_negatives = get_data('/common/home/aj780/machine_learning/CCA Data/embeddings_train1.pkl', None)

print("Train Data reading done..!")
val_ids, image_val_data, text_val_data, text_val_negatives = get_data('/common/home/aj780/machine_learning/CCA Data/embeddings_val1.pkl', None)
print("Val Data reading done..!")

test_ids, image_test_data, text_test_data, text_test_negatives = get_data('/common/home/aj780/machine_learning/CCA Data/embeddings_test1.pkl', None)
print("Test Data reading done..!")




n_components = [1,5, 10, 15, 20,50, 100,200,500, 1000]
i = 0
metric_data_im2recipe = pd.DataFrame(columns = ['n_comp','medR','r@1', 'r@5','r@10'], index=range(len(n_components)))
metric_data_recipe2im = pd.DataFrame(columns = ['n_comp','medR','r@1', 'r@5','r@10'], index=range(len(n_components)))
embeddings_type = "averageEmbeddings"
output_dir = "CCA_Final_Part2_Triplet"

embeddings_dir = output_dir + "/" + embeddings_type 


learning_rate = 0.001
margin = 0.4
epochs = 10
batch_size = 512
reg_lambda = 1e-5
for n_comp in n_components:
    
    layer_sizes = [n_comp]
    model_out_dir = embeddings_dir +  "/" + str(n_comp)
    Path(model_out_dir).mkdir(parents=True, exist_ok=True)
    
    
    model = train_model(model_out_dir, image_train_data, text_train_data, text_train_negatives, 
                       image_val_data, text_val_data, text_val_negatives,
                       layer_sizes, n_comp, 1024, 1024, 1024, 
                        learning_rate, margin, epochs, batch_size, reg_lambda)
    
    dataX, dataY = predict_model(model,image_test_data, text_test_data, text_test_negatives)
    medR, recall = evaluation(dataX, dataY, test_ids, True , 1000, 10)
    metric_data_im2recipe.loc[i] = [n_comp, medR, recall[1], recall[5], recall[10]]
    
    medR, recall = evaluation(dataX, dataY, test_ids, False , 1000, 10)
    metric_data_recipe2im.loc[i] = [n_comp, medR, recall[1], recall[5], recall[10]]
    
    
    print("n_comp: " + str(n_comp) + " done..!")
    i+=1
    
metric_data_im2recipe.to_csv(embeddings_dir + "/metrics_" + embeddings_type + "_im2recipe.csv", index=False)
metric_data_recipe2im.to_csv(embeddings_dir + "/metrics_" + embeddings_type + "_recipe2im.csv", index=False)
# Out:
# Train Data reading done..!
# Val Data reading done..!
# Test Data reading done..!
# Epoch 1/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.3971 - val_loss: 0.3966
# Epoch 2/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.3945 - val_loss: 0.3934
# Epoch 3/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.3889 - val_loss: 0.3860
# Epoch 4/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.3758 - val_loss: 0.3687
# Epoch 5/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.3479 - val_loss: 0.3380
# Epoch 6/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.3132 - val_loss: 0.3118
# Epoch 7/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.2873 - val_loss: 0.2943
# Epoch 8/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.2688 - val_loss: 0.2819
# Epoch 9/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.2548 - val_loss: 0.2725
# Epoch 10/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.2438 - val_loss: 0.2653
# n_comp: 1 done..!
# Epoch 1/10
# 550/550 [==============================] - 4s 6ms/step - loss: 0.3789 - val_loss: 0.3718
# Epoch 2/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.3406 - val_loss: 0.3049
# Epoch 3/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.2444 - val_loss: 0.2258
# Epoch 4/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.1923 - val_loss: 0.1958
# Epoch 5/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.1634 - val_loss: 0.1729
# Epoch 6/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.1407 - val_loss: 0.1551
# Epoch 7/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.1234 - val_loss: 0.1417
# Epoch 8/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.1105 - val_loss: 0.1317
# Epoch 9/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.1008 - val_loss: 0.1239
# Epoch 10/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.0932 - val_loss: 0.1178
# n_comp: 5 done..!
# Epoch 1/10
# 550/550 [==============================] - 3s 4ms/step - loss: 0.3606 - val_loss: 0.3483
# Epoch 2/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.2965 - val_loss: 0.2485
# Epoch 3/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.1868 - val_loss: 0.1747
# Epoch 4/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.1367 - val_loss: 0.1435
# Epoch 5/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.1099 - val_loss: 0.1234
# Epoch 6/10
# 550/550 [==============================] - 1s 3ms/step - loss: 0.0917 - val_loss: 0.1090
# Epoch 7/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.0786 - val_loss: 0.0982
# Epoch 8/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.0687 - val_loss: 0.0897
# Epoch 9/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.0612 - val_loss: 0.0831
# Epoch 10/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.0554 - val_loss: 0.0778
# n_comp: 10 done..!
# Epoch 1/10
# 550/550 [==============================] - 3s 5ms/step - loss: 0.3392 - val_loss: 0.3222
# Epoch 2/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.2543 - val_loss: 0.2147
# Epoch 3/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.1603 - val_loss: 0.1572
# Epoch 4/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.1142 - val_loss: 0.1241
# Epoch 5/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.0859 - val_loss: 0.1028
# Epoch 6/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.0683 - val_loss: 0.0886
# Epoch 7/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.0567 - val_loss: 0.0786
# Epoch 8/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.0487 - val_loss: 0.0713
# Epoch 9/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.0430 - val_loss: 0.0657
# Epoch 10/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.0386 - val_loss: 0.0613
# n_comp: 15 done..!
# Epoch 1/10
# 550/550 [==============================] - 3s 5ms/step - loss: 0.3258 - val_loss: 0.3075
# Epoch 2/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.2334 - val_loss: 0.1947
# Epoch 3/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.1349 - val_loss: 0.1339
# Epoch 4/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.0915 - val_loss: 0.1049
# Epoch 5/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.0691 - val_loss: 0.0878
# Epoch 6/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.0557 - val_loss: 0.0765
# Epoch 7/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.0468 - val_loss: 0.0686
# Epoch 8/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.0406 - val_loss: 0.0627
# Epoch 9/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.0360 - val_loss: 0.0581
# Epoch 10/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.0325 - val_loss: 0.0544
# n_comp: 20 done..!
# Epoch 1/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.2176 - val_loss: 0.1790
# Epoch 2/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.1013 - val_loss: 0.1012
# Epoch 3/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.0576 - val_loss: 0.0748
# Epoch 4/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.0411 - val_loss: 0.0614
# Epoch 5/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.0325 - val_loss: 0.0531
# Epoch 6/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.0272 - val_loss: 0.0474
# Epoch 7/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.0236 - val_loss: 0.0433
# Epoch 8/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.0210 - val_loss: 0.0402
# Epoch 9/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.0191 - val_loss: 0.0377
# Epoch 10/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.0176 - val_loss: 0.0357
# n_comp: 50 done..!
# Epoch 1/10
# 550/550 [==============================] - 4s 6ms/step - loss: 0.0973 - val_loss: 0.0956
# Epoch 2/10
# 550/550 [==============================] - 3s 5ms/step - loss: 0.0466 - val_loss: 0.0665
# Epoch 3/10
# 550/550 [==============================] - 3s 5ms/step - loss: 0.0323 - val_loss: 0.0540
# Epoch 4/10
# 550/550 [==============================] - 3s 5ms/step - loss: 0.0257 - val_loss: 0.0467
# Epoch 5/10
# 550/550 [==============================] - 3s 5ms/step - loss: 0.0219 - val_loss: 0.0420
# Epoch 6/10
# 550/550 [==============================] - 3s 5ms/step - loss: 0.0193 - val_loss: 0.0385
# Epoch 7/10
# 550/550 [==============================] - 3s 5ms/step - loss: 0.0175 - val_loss: 0.0358
# Epoch 8/10
# 550/550 [==============================] - 3s 5ms/step - loss: 0.0161 - val_loss: 0.0337
# Epoch 9/10
# 550/550 [==============================] - 3s 5ms/step - loss: 0.0150 - val_loss: 0.0320
# Epoch 10/10
# 550/550 [==============================] - 3s 5ms/step - loss: 0.0142 - val_loss: 0.0306
# n_comp: 100 done..!
# Epoch 1/10
# 550/550 [==============================] - 4s 7ms/step - loss: 0.0319 - val_loss: 0.0581
# Epoch 2/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.0250 - val_loss: 0.0495
# Epoch 3/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.0213 - val_loss: 0.0440
# Epoch 4/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.0189 - val_loss: 0.0401
# Epoch 5/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.0173 - val_loss: 0.0373
# Epoch 6/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.0160 - val_loss: 0.0350
# Epoch 7/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.0151 - val_loss: 0.0332
# Epoch 8/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.0143 - val_loss: 0.0317
# Epoch 9/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.0137 - val_loss: 0.0304
# Epoch 10/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.0132 - val_loss: 0.0293
# n_comp: 200 done..!
# Epoch 1/10
# 550/550 [==============================] - 6s 11ms/step - loss: 0.0122 - val_loss: 0.0236
# Epoch 2/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0121 - val_loss: 0.0234
# Epoch 3/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0120 - val_loss: 0.0231
# Epoch 4/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0119 - val_loss: 0.0229
# Epoch 5/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0118 - val_loss: 0.0227
# Epoch 6/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0118 - val_loss: 0.0225
# Epoch 7/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0117 - val_loss: 0.0224
# Epoch 8/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0116 - val_loss: 0.0222
# Epoch 9/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0116 - val_loss: 0.0220
# Epoch 10/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0115 - val_loss: 0.0219
# n_comp: 500 done..!
# Epoch 1/10
# 550/550 [==============================] - 10s 17ms/step - loss: 0.0131 - val_loss: 0.0202
# Epoch 2/10
# 550/550 [==============================] - 8s 15ms/step - loss: 0.0131 - val_loss: 0.0202
# Epoch 3/10
# 550/550 [==============================] - 8s 15ms/step - loss: 0.0131 - val_loss: 0.0202
# Epoch 4/10
# 550/550 [==============================] - 8s 15ms/step - loss: 0.0131 - val_loss: 0.0201
# Epoch 5/10
# 550/550 [==============================] - 8s 15ms/step - loss: 0.0130 - val_loss: 0.0201
# Epoch 6/10
# 550/550 [==============================] - 8s 15ms/step - loss: 0.0130 - val_loss: 0.0201
# Epoch 7/10
# 550/550 [==============================] - 8s 15ms/step - loss: 0.0130 - val_loss: 0.0200
# Epoch 8/10
# 550/550 [==============================] - 8s 15ms/step - loss: 0.0130 - val_loss: 0.0200
# Epoch 9/10
# 550/550 [==============================] - 8s 15ms/step - loss: 0.0130 - val_loss: 0.0200
# Epoch 10/10
# 550/550 [==============================] - 8s 15ms/step - loss: 0.0130 - val_loss: 0.0199
# n_comp: 1000 done..!

# %% [markdown]
# ### Running model on ingredients embeddings

# %%
train_ids, image_train_data, text_train_data, text_train_negatives = get_data('/common/home/aj780/machine_learning/CCA Data/embeddings_train1.pkl',
                                                                  '/common/home/aj780/machine_learning/CCA Data/ingredients_embeddings_train.pkl')

val_ids, image_val_data, text_val_data, text_val_negatives = get_data('/common/home/aj780/machine_learning/CCA Data/embeddings_val1.pkl',
                                                                  '/common/home/aj780/machine_learning/CCA Data/ingredients_embeddings_val.pkl')

test_ids, image_test_data, text_test_data, text_test_negatives = get_data('/common/home/aj780/machine_learning/CCA Data/embeddings_test1.pkl',
                                                                  '/common/home/aj780/machine_learning/CCA Data/ingredients_embeddings_test.pkl')




n_components = [1,5, 10, 15, 20,50, 100,200,500, 1000]
i = 0
metric_data_im2recipe = pd.DataFrame(columns = ['n_comp','medR','r@1', 'r@5','r@10'], index=range(len(n_components)))
metric_data_recipe2im = pd.DataFrame(columns = ['n_comp','medR','r@1', 'r@5','r@10'], index=range(len(n_components)))
embeddings_type = "Ingredients"
output_dir = "CCA_Final_Part2_Triplet"

embeddings_dir = output_dir + "/" + embeddings_type 


learning_rate = 0.001
margin = 0.4
epochs = 10
batch_size = 512
reg_lambda = 1e-5
for n_comp in n_components:
    
    layer_sizes = [n_comp]
    model_out_dir = embeddings_dir +  "/" + str(n_comp)
    Path(model_out_dir).mkdir(parents=True, exist_ok=True)
    
    
    model = train_model(model_out_dir, image_train_data, text_train_data, text_train_negatives, 
                       image_val_data, text_val_data, text_val_negatives,
                       layer_sizes, n_comp, 1024, 1024, 1024, 
                        learning_rate, margin, epochs, batch_size, reg_lambda)
    
    dataX, dataY = predict_model(model,image_test_data, text_test_data, text_test_negatives)
    medR, recall = evaluation(dataX, dataY, test_ids, True , 1000, 10)
    metric_data_im2recipe.loc[i] = [n_comp, medR, recall[1], recall[5], recall[10]]
    
    medR, recall = evaluation(dataX, dataY, test_ids, False , 1000, 10)
    metric_data_recipe2im.loc[i] = [n_comp, medR, recall[1], recall[5], recall[10]]
    
    
    print("n_comp: " + str(n_comp) + " done..!")
    i+=1
    
metric_data_im2recipe.to_csv(embeddings_dir + "/metrics_" + embeddings_type + "_im2recipe.csv", index=False)
metric_data_recipe2im.to_csv(embeddings_dir + "/metrics_" + embeddings_type + "_recipe2im.csv", index=False)
# Out:
# Epoch 1/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.3981 - val_loss: 0.3978
# Epoch 2/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.3963 - val_loss: 0.3951
# Epoch 3/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.3907 - val_loss: 0.3855
# Epoch 4/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.3693 - val_loss: 0.3473
# Epoch 5/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.3100 - val_loss: 0.2840
# Epoch 6/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.2637 - val_loss: 0.2584
# Epoch 7/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.2451 - val_loss: 0.2475
# Epoch 8/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.2355 - val_loss: 0.2414
# Epoch 9/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.2296 - val_loss: 0.2377
# Epoch 10/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.2257 - val_loss: 0.2354
# n_comp: 1 done..!
# Epoch 1/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.3887 - val_loss: 0.3866
# Epoch 2/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.3788 - val_loss: 0.3726
# Epoch 3/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.3532 - val_loss: 0.3336
# Epoch 4/10
# 550/550 [==============================] - 4s 7ms/step - loss: 0.2862 - val_loss: 0.2490
# Epoch 5/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.2071 - val_loss: 0.1947
# Epoch 6/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.1676 - val_loss: 0.1702
# Epoch 7/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.1477 - val_loss: 0.1563
# Epoch 8/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.1353 - val_loss: 0.1470
# Epoch 9/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.1264 - val_loss: 0.1402
# Epoch 10/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.1197 - val_loss: 0.1350
# n_comp: 5 done..!
# Epoch 1/10
# 550/550 [==============================] - 4s 4ms/step - loss: 0.3751 - val_loss: 0.3683
# Epoch 2/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.3445 - val_loss: 0.3206
# Epoch 3/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.2649 - val_loss: 0.2256
# Epoch 4/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.
10
# 550/550 [==============================] - 8s 14ms/step - loss: 0.0234 - val_loss: 0.0373
# Epoch 9/10
# 550/550 [==============================] - 8s 14ms/step - loss: 0.0232 - val_loss: 0.0369
# Epoch 10/10
# 550/550 [==============================] - 8s 14ms/step - loss: 0.0230 - val_loss: 0.0366
# n_comp: 1000 done..!

# %% [markdown]
# ### Running model on instructions embeddings

# %%
train_ids, image_train_data, text_train_data, text_train_negatives = get_data('/common/home/aj780/machine_learning/CCA Data/embeddings_train1.pkl',
                                                                  '/common/home/aj780/machine_learning/CCA Data/instructions_embeddings_train.pkl')

val_ids, image_val_data, text_val_data, text_val_negatives = get_data('/common/home/aj780/machine_learning/CCA Data/embeddings_val1.pkl',
                                                                  '/common/home/aj780/machine_learning/CCA Data/instructions_embeddings_val.pkl')

test_ids, image_test_data, text_test_data, text_test_negatives = get_data('/common/home/aj780/machine_learning/CCA Data/embeddings_test1.pkl',
                                                                  '/common/home/aj780/machine_learning/CCA Data/instructions_embeddings_test.pkl')






n_components = [1,5, 10, 15, 20,50, 100,200,500, 1000]
i = 0
metric_data_im2recipe = pd.DataFrame(columns = ['n_comp','medR','r@1', 'r@5','r@10'], index=range(len(n_components)))
metric_data_recipe2im = pd.DataFrame(columns = ['n_comp','medR','r@1', 'r@5','r@10'], index=range(len(n_components)))
embeddings_type = "Instructions"
output_dir = "CCA_Final_Part2_Triplet"

embeddings_dir = output_dir + "/" + embeddings_type 


learning_rate = 0.001
margin = 0.4
epochs = 10
batch_size = 512
reg_lambda = 1e-5
for n_comp in n_components:
    
    layer_sizes = [n_comp]
    model_out_dir = embeddings_dir +  "/" + str(n_comp)
    Path(model_out_dir).mkdir(parents=True, exist_ok=True)
    
    
    model = train_model(model_out_dir, image_train_data, text_train_data, text_train_negatives, 
                       image_val_data, text_val_data, text_val_negatives,
                       layer_sizes, n_comp, 1024, 1024, 1024, 
                        learning_rate, margin, epochs, batch_size, reg_lambda)
    
    dataX, dataY = predict_model(model,image_test_data, text_test_data, text_test_negatives)
    medR, recall = evaluation(dataX, dataY, test_ids, True , 1000, 10)
    metric_data_im2recipe.loc[i] = [n_comp, medR, recall[1], recall[5], recall[10]]
    
    medR, recall = evaluation(dataX, dataY, test_ids, False , 1000, 10)
    metric_data_recipe2im.loc[i] = [n_comp, medR, recall[1], recall[5], recall[10]]
    
    
    print("n_comp: " + str(n_comp) + " done..!")
    i+=1
    
metric_data_im2recipe.to_csv(embeddings_dir + "/metrics_" + embeddings_type + "_im2recipe.csv", index=False)
metric_data_recipe2im.to_csv(embeddings_dir + "/metrics_" + embeddings_type + "_recipe2im.csv", index=False)
# Out:
# Epoch 1/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.3973 - val_loss: 0.3972
# Epoch 2/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.3956 - val_loss: 0.3949
# Epoch 3/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.3915 - val_loss: 0.3893
# Epoch 4/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.3809 - val_loss: 0.3737
# Epoch 5/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.3552 - val_loss: 0.3434
# Epoch 6/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.3261 - val_loss: 0.3237
# Epoch 7/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.3111 - val_loss: 0.3154
# Epoch 8/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.3039 - val_loss: 0.3113
# Epoch 9/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.2999 - val_loss: 0.3089
# Epoch 10/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.2972 - val_loss: 0.3071
# n_comp: 1 done..!
# Epoch 1/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.3825 - val_loss: 0.3796
# Epoch 2/10
# 550/550 [==============================] - 1s 3ms/step - loss: 0.3662 - val_loss: 0.3569
# Epoch 3/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.3301 - val_loss: 0.3152
# Epoch 4/10
# 550/550 [==============================] - 1s 3ms/step - loss: 0.2884 - val_loss: 0.2813
# Epoch 5/10
# 550/550 [==============================] - 1s 3ms/step - loss: 0.2533 - val_loss: 0.2510
# Epoch 6/10
# 550/550 [==============================] - 1s 3ms/step - loss: 0.2218 - val_loss: 0.2256
# Epoch 7/10
# 550/550 [==============================] - 1s 3ms/step - loss: 0.1971 - val_loss: 0.2069
# Epoch 8/10
# 550/550 [==============================] - 1s 3ms/step - loss: 0.1793 - val_loss: 0.1936
# Epoch 9/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.1663 - val_loss: 0.1839
# Epoch 10/10
# 550/550 [==============================] - 1s 3ms/step - loss: 0.1565 - val_loss: 0.1764
# n_comp: 5 done..!
# Epoch 1/10
# 550/550 [==============================] - 3s 4ms/step - loss: 0.3745 - val_loss: 0.3714
# Epoch 2/10
# 550/550 [==============================] - 1s 3ms/step - loss: 0.3553 - val_loss: 0.3467
# Epoch 3/10
# 550/550 [==============================] - 1s 3ms/step - loss: 0.3143 - val_loss: 0.2942
# Epoch 4/10
# 550/550 [==============================] - 1s 3ms/step - loss: 0.2516 - val_loss: 0.2391
# Epoch 5/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.2013 - val_loss: 0.2007
# Epoch 6/10
# 550/550 [==============================] - 1s 3ms/step - loss: 0.1665 - val_loss: 0.1746
# Epoch 7/10
# 550/550 [==============================] - 1s 3ms/step - loss: 0.1429 - val_loss: 0.1567
# Epoch 8/10
# 550/550 [==============================] - 1s 3ms/step - loss: 0.1265 - val_loss: 0.1439
# Epoch 9/10
# 550/550 [==============================] - 1s 3ms/step - loss: 0.1145 - val_loss: 0.1343
# Epoch 10/10
# 550/550 [==============================] - 1s 3ms/step - loss: 0.1055 - val_loss: 0.1270
# n_comp: 10 done..!
# Epoch 1/10
# 550/550 [==============================] - 3s 4ms/step - loss: 0.3639 - val_loss: 0.3589
# Epoch 2/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.3356 - val_loss: 0.3214
# Epoch 3/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.2783 - val_loss: 0.2580
# Epoch 4/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.2165 - val_loss: 0.2108
# Epoch 5/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.1733 - val_loss: 0.1778
# Epoch 6/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.1431 - val_loss: 0.1541
# Epoch 7/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.1215 - val_loss: 0.1368
# Epoch 8/10
# 550/550 [==============================] - 1s 3ms/step - loss: 0.1058 - val_loss: 0.1239
# Epoch 9/10
# 550/550 [==============================] - 1s 3ms/step - loss: 0.0940 - val_loss: 0.1139
# Epoch 10/10
# 550/550 [==============================] - 1s 3ms/step - loss: 0.0849 - val_loss: 0.1061
# n_comp: 15 done..!
# Epoch 1/10
# 550/550 [==============================] - 3s 4ms/step - loss: 0.3483 - val_loss: 0.3418
# Epoch 2/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.3092 - val_loss: 0.2912
# Epoch 3/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.2403 - val_loss: 0.2237
# Epoch 4/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.1795 - val_loss: 0.1785
# Epoch 5/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.1402 - val_loss: 0.1486
# Epoch 6/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.1141 - val_loss: 0.1281
# Epoch 7/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.0963 - val_loss: 0.1136
# Epoch 8/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.0835 - val_loss: 0.1029
# Epoch 9/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.0742 - val_loss: 0.0948
# Epoch 10/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.0672 - val_loss: 0.0884
# n_comp: 20 done..!
# Epoch 1/10
# 550/550 [==============================] - 3s 5ms/step - loss: 0.2787 - val_loss: 0.2632
# Epoch 2/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.2008 - val_loss: 0.1864
# Epoch 3/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.1350 - val_loss: 0.1407
# Epoch 4/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.0994 - val_loss: 0.1144
# Epoch 5/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.0786 - val_loss: 0.0978
# Epoch 6/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.0654 - val_loss: 0.0864
# Epoch 7/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.0564 - val_loss: 0.0783
# Epoch 8/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.0500 - val_loss: 0.0722
# Epoch 9/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.0451 - val_loss: 0.0674
# Epoch 10/10
# 550/550 [==============================] - 2s 4ms/step - loss: 0.0414 - val_loss: 0.0636
# n_comp: 50 done..!
# Epoch 1/10
# 550/550 [==============================] - 6s 6ms/step - loss: 0.1748 - val_loss: 0.1651
# Epoch 2/10
# 550/550 [==============================] - 3s 5ms/step - loss: 0.1071 - val_loss: 0.1188
# Epoch 3/10
# 550/550 [==============================] - 3s 5ms/step - loss: 0.0750 - val_loss: 0.0950
# Epoch 4/10
# 550/550 [==============================] - 3s 5ms/step - loss: 0.0585 - val_loss: 0.0809
# Epoch 5/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.0487 - val_loss: 0.0716
# Epoch 6/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.0424 - val_loss: 0.0651
# Epoch 7/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.0379 - val_loss: 0.0603
# Epoch 8/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.0346 - val_loss: 0.0565
# Epoch 9/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.0320 - val_loss: 0.0535
# Epoch 10/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.0300 - val_loss: 0.0510
# n_comp: 100 done..!
# Epoch 1/10
# 550/550 [==============================] - 5s 8ms/step - loss: 0.0821 - val_loss: 0.1022
# Epoch 2/10
# 550/550 [==============================] - 4s 7ms/step - loss: 0.0611 - val_loss: 0.0847
# Epoch 3/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.0497 - val_loss: 0.0738
# Epoch 4/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.0427 - val_loss: 0.0664
# Epoch 5/10
# 550/550 [==============================] - 4s 6ms/step - loss: 0.0380 - val_loss: 0.0610
# Epoch 6/10
# 550/550 [==============================] - 4s 7ms/step - loss: 0.0346 - val_loss: 0.0569
# Epoch 7/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.0320 - val_loss: 0.0537
# Epoch 8/10
# 550/550 [==============================] - 4s 7ms/step - loss: 0.0300 - val_loss: 0.0510
# Epoch 9/10
# 550/550 [==============================] - 4s 7ms/step - loss: 0.0283 - val_loss: 0.0488
# Epoch 10/10
# 550/550 [==============================] - 4s 7ms/step - loss: 0.0269 - val_loss: 0.0470
# n_comp: 200 done..!
# Epoch 1/10
# 550/550 [==============================] - 7s 13ms/step - loss: 0.0316 - val_loss: 0.0537
# Epoch 2/10
# 550/550 [==============================] - 5s 10ms/step - loss: 0.0299 - val_loss: 0.0513
# Epoch 3/10
# 550/550 [==============================] - 6s 11ms/step - loss: 0.0285 - val_loss: 0.0494
# Epoch 4/10
# 550/550 [==============================] - 6s 11ms/step - loss: 0.0273 - val_loss: 0.0478
# Epoch 5/10
# 550/550 [==============================] - 6s 11ms/step - loss: 0.0263 - val_loss: 0.0463
# Epoch 6/10
# 550/550 [==============================] - 6s 11ms/step - loss: 0.0255 - val_loss: 0.0451
# Epoch 7/10
# 550/550 [==============================] - 6s 11ms/step - loss: 0.0248 - val_loss: 0.0440
# Epoch 8/10
# 550/550 [==============================] - 6s 11ms/step - loss: 0.0242 - val_loss: 0.0431
# Epoch 9/10
# 550/550 [==============================] - 6s 10ms/step - loss: 0.0236 - val_loss: 0.0422
# Epoch 10/10
# 550/550 [==============================] - 6s 10ms/step - loss: 0.0232 - val_loss: 0.0414
# n_comp: 500 done..!
# Epoch 1/10
# 550/550 [==============================] - 10s 18ms/step - loss: 0.0250 - val_loss: 0.0416
# Epoch 2/10
# 550/550 [==============================] - 9s 16ms/step - loss: 0.0244 - val_loss: 0.0408
# Epoch 3/10
# 550/550 [==============================] - 9s 16ms/step - loss: 0.0239 - val_loss: 0.0402
# Epoch 4/10
# 550/550 [==============================] - 9s 16ms/step - loss: 0.0235 - val_loss: 0.0396
# Epoch 5/10
# 550/550 [==============================] - 9s 16ms/step - loss: 0.0232 - val_loss: 0.0391
# Epoch 6/10
# 550/550 [==============================] - 9s 16ms/step - loss: 0.0229 - val_loss: 0.0387
# Epoch 7/10
# 550/550 [==============================] - 9s 17ms/step - loss: 0.0226 - val_loss: 0.0383
# Epoch 8/10
# 550/550 [==============================] - 9s 16ms/step - loss: 0.0224 - val_loss: 0.0379
# Epoch 9/10
# 550/550 [==============================] - 9s 16ms/step - loss: 0.0221 - val_loss: 0.0376
# Epoch 10/10
# 550/550 [==============================] - 9s 16ms/step - loss: 0.0219 - val_loss: 0.0372
# n_comp: 1000 done..!

# %% [markdown]
# ### Running model on title embeddings

# %%
train_ids, image_train_data, text_train_data, text_train_negatives = get_data('/common/home/aj780/machine_learning/CCA Data/embeddings_train1.pkl',
                                                                  '/common/home/aj780/machine_learning/CCA Data/title_embeddings_train.pkl')

val_ids, image_val_data, text_val_data, text_val_negatives = get_data('/common/home/aj780/machine_learning/CCA Data/embeddings_val1.pkl',
                                                                  '/common/home/aj780/machine_learning/CCA Data/title_embeddings_val.pkl')

test_ids, image_test_data, text_test_data, text_test_negatives = get_data('/common/home/aj780/machine_learning/CCA Data/embeddings_test1.pkl',
                                                                  '/common/home/aj780/machine_learning/CCA Data/title_embeddings_test.pkl')





n_components = [1,5, 10, 15, 20,50, 100,200,500, 1000]
i = 0
metric_data_im2recipe = pd.DataFrame(columns = ['n_comp','medR','r@1', 'r@5','r@10'], index=range(len(n_components)))
metric_data_recipe2im = pd.DataFrame(columns = ['n_comp','medR','r@1', 'r@5','r@10'], index=range(len(n_components)))
embeddings_type = "Title"
output_dir = "CCA_Final_Part2_Triplet"

embeddings_dir = output_dir + "/" + embeddings_type 


learning_rate = 0.001
margin = 0.4
epochs = 10
batch_size = 512
reg_lambda = 1e-5
for n_comp in n_components:
    
    layer_sizes = [n_comp]
    model_out_dir = embeddings_dir +  "/" + str(n_comp)
    Path(model_out_dir).mkdir(parents=True, exist_ok=True)
    
    
    model = train_model(model_out_dir, image_train_data, text_train_data, text_train_negatives, 
                       image_val_data, text_val_data, text_val_negatives,
                       layer_sizes, n_comp, 1024, 1024, 1024, 
                        learning_rate, margin, epochs, batch_size, reg_lambda)
    
    dataX, dataY = predict_model(model,image_test_data, text_test_data, text_test_negatives)
    medR, recall = evaluation(dataX, dataY, test_ids, True , 1000, 10)
    metric_data_im2recipe.loc[i] = [n_comp, medR, recall[1], recall[5], recall[10]]
    
    medR, recall = evaluation(dataX, dataY, test_ids, False , 1000, 10)
    metric_data_recipe2im.loc[i] = [n_comp, medR, recall[1], recall[5], recall[10]]
    
    
    print("n_comp: " + str(n_comp) + " done..!")
    i+=1
    
metric_data_im2recipe.to_csv(embeddings_dir + "/metrics_" + embeddings_type + "_im2recipe.csv", index=False)
metric_data_recipe2im.to_csv(embeddings_dir + "/metrics_" + embeddings_type + "_recipe2im.csv", index=False)
# Out:
# Epoch 1/10
# 550/550 [==============================] - 2s 3ms/step - loss: 0.3984 - val_loss: 0.3984
# Epoch 2/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.3977 - val_loss: 0.3976
# Epoch 3/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.3965 - val_loss: 0.3963
# Epoch 4/10
# 550/550 [==============================] - 1s 2ms/step - loss: 0.
10
# 550/550 [==============================] - 3s 5ms/step - loss: 0.0656 - val_loss: 0.0946
# Epoch 10/10
# 550/550 [==============================] - 3s 5ms/step - loss: 0.0619 - val_loss: 0.0908
# n_comp: 100 done..!
# Epoch 1/10
# 550/550 [==============================] - 5s 8ms/step - loss: 0.1537 - val_loss: 0.1686
# Epoch 2/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.1176 - val_loss: 0.1408
# Epoch 3/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.0961 - val_loss: 0.1232
# Epoch 4/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.0826 - val_loss: 0.1115
# Epoch 5/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.0736 - val_loss: 0.1032
# Epoch 6/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.0673 - val_loss: 0.0970
# Epoch 7/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.0626 - val_loss: 0.0922
# Epoch 8/10
# 550/550 [==============================] - 4s 7ms/step - loss: 0.0589 - val_loss: 0.0883
# Epoch 9/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.0559 - val_loss: 0.0852
# Epoch 10/10
# 550/550 [==============================] - 3s 6ms/step - loss: 0.0535 - val_loss: 0.0825
# n_comp: 200 done..!
# Epoch 1/10
# 550/550 [==============================] - 7s 11ms/step - loss: 0.0764 - val_loss: 0.1085
# Epoch 2/10
# 550/550 [==============================] - 6s 10ms/step - loss: 0.0694 - val_loss: 0.1014
# Epoch 3/10
# 550/550 [==============================] - 6s 10ms/step - loss: 0.0641 - val_loss: 0.0959
# Epoch 4/10
# 550/550 [==============================] - 5s 10ms/step - loss: 0.0601 - val_loss: 0.0916
# Epoch 5/10
# 550/550 [==============================] - 5s 10ms/step - loss: 0.0569 - val_loss: 0.0881
# Epoch 6/10
# 550/550 [==============================] - 5s 10ms/step - loss: 0.0543 - val_loss: 0.0851
# Epoch 7/10
# 550/550 [==============================] - 5s 10ms/step - loss: 0.0522 - val_loss: 0.0826
# Epoch 8/10
# 550/550 [==============================] - 5s 10ms/step - loss: 0.0504 - val_loss: 0.0805
# Epoch 9/10
# 550/550 [==============================] - 5s 10ms/step - loss: 0.0488 - val_loss: 0.0787
# Epoch 10/10
# 550/550 [==============================] - 5s 10ms/step - loss: 0.0475 - val_loss: 0.0771
# n_comp: 500 done..!
# Epoch 1/10
# 550/550 [==============================] - 10s 17ms/step - loss: 0.0561 - val_loss: 0.0883
# Epoch 2/10
# 550/550 [==============================] - 9s 16ms/step - loss: 0.0538 - val_loss: 0.0856
# Epoch 3/10
# 550/550 [==============================] - 9s 16ms/step - loss: 0.0519 - val_loss: 0.0834
# Epoch 4/10
# 550/550 [==============================] - 8s 15ms/step - loss: 0.0503 - val_loss: 0.0815
# Epoch 5/10
# 550/550 [==============================] - 8s 15ms/step - loss: 0.0489 - val_loss: 0.0798
# Epoch 6/10
# 550/550 [==============================] - 9s 15ms/step - loss: 0.0478 - val_loss: 0.0784
# Epoch 7/10
# 550/550 [==============================] - 10s 17ms/step - loss: 0.0468 - val_loss: 0.0770
# Epoch 8/10
# 550/550 [==============================] - 9s 17ms/step - loss: 0.0459 - val_loss: 0.0759
# Epoch 9/10
# 550/550 [==============================] - 8s 15ms/step - loss: 0.0451 - val_loss: 0.0748
# Epoch 10/10
# 550/550 [==============================] - 9s 17ms/step - loss: 0.0444 - val_loss: 0.0739
# n_comp: 1000 done..!

# %% [markdown]
# ### Running ablation studies on hyperparameters - learning rate

# %%
train_ids, image_train_data, text_train_data, text_train_negatives = get_data('/common/home/aj780/machine_learning/CCA Data/embeddings_train1.pkl', None)

print("Train Data reading done..!")
val_ids, image_val_data, text_val_data, text_val_negatives = get_data('/common/home/aj780/machine_learning/CCA Data/embeddings_val1.pkl', None)
print("Val Data reading done..!")

test_ids, image_test_data, text_test_data, text_test_negatives = get_data('/common/home/aj780/machine_learning/CCA Data/embeddings_test1.pkl', None)
print("Test Data reading done..!")




learning_rates = [0.1, 0.01, 0.05, 0.001,0.005, 0.0001, 0.0005]
i = 0
metric_data_im2recipe = pd.DataFrame(columns = ['learning_rate','medR','r@1', 'r@5','r@10'], index=range(len(learning_rates)))
metric_data_recipe2im = pd.DataFrame(columns = ['learning_rate','medR','r@1', 'r@5','r@10'], index=range(len(learning_rates)))
embeddings_type = "learningrate"
output_dir = "CCA_Final_Part2_Triplet"

embeddings_dir = output_dir + "/" + embeddings_type 


n_component = 200
margin = 0.4
epochs = 10
batch_size = 512
reg_lambda = 1e-5
layer_sizes = [n_component]
for lr in learning_rates:
    
    model_out_dir = embeddings_dir +  "/" + str(lr)
    Path(model_out_dir).mkdir(parents=True, exist_ok=True)
    
    
    model = train_model(model_out_dir, image_train_data, text_train_data, text_train_negatives, 
                       image_val_data, text_val_data, text_val_negatives,
                       layer_sizes, n_component, 1024, 1024, 1024, 
                        lr, margin, epochs, batch_size, reg_lambda)
    
    dataX, dataY = predict_model(model,image_test_data, text_test_data, text_test_negatives)
    medR, recall = evaluation(dataX, dataY, test_ids, True , 1000, 10)
    metric_data_im2recipe.loc[i] = [lr, medR, recall[1], recall[5], recall[10]]
    
    medR, recall = evaluation(dataX, dataY, test_ids, False , 1000, 10)
    metric_data_recipe2im.loc[i] = [lr, medR, recall[1], recall[5], recall[10]]
    
    
    print("learning rate: " + str(lr) + " done..!")
    i+=1
    
metric_data_im2recipe.to_csv(embeddings_dir + "/lr_metrics_" + embeddings_type + "_im2recipe.csv", index=False)
metric_data_recipe2im.to_csv(embeddings_dir + "/lr_metrics_" + embeddings_type + "_recipe2im.csv", index=False)
# Out:
# Train Data reading done..!
# Val Data reading done..!
# Test Data reading done..!
# Epoch 1/10
# 550/550 [==============================] - 6s 10ms/step - loss: 0.0096 - val_loss: 0.0147
# Epoch 2/10
# 550/550 [==============================] - 5s 8ms/step - loss: 0.0066 - val_loss: 0.0131
# Epoch 3/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0060 - val_loss: 0.0124
# Epoch 4/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0057 - val_loss: 0.0120
# Epoch 5/10
# 550/550 [==============================] - 4s 8ms/step - loss: 0.0055 - val_loss: 0.0118
# Epoch 6/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0053 - val_loss: 0.0116
# Epoch 7/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0051 - val_loss: 0.0116
# Epoch 8/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0050 - val_loss: 0.0115
# Epoch 9/10
# 550/550 [==============================] - 6s 11ms/step - loss: 0.0048 - val_loss: 0.0114
# Epoch 10/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0047 - val_loss: 0.0114
# learning rate: 0.1 done..!
# Epoch 1/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0189 - val_loss: 0.0294
# Epoch 2/10
# 550/550 [==============================] - 4s 7ms/step - loss: 0.0114 - val_loss: 0.0234
# Epoch 3/10
# 550/550 [==============================] - 4s 8ms/step - loss: 0.0097 - val_loss: 0.0207
# Epoch 4/10
# 550/550 [==============================] - 4s 7ms/step - loss: 0.0088 - val_loss: 0.0190
# Epoch 5/10
# 550/550 [==============================] - 4s 8ms/step - loss: 0.0083 - val_loss: 0.0179
# Epoch 6/10
# 550/550 [==============================] - 5s 8ms/step - loss: 0.0079 - val_loss: 0.0171
# Epoch 7/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0076 - val_loss: 0.0165
# Epoch 8/10
# 550/550 [==============================] - 4s 8ms/step - loss: 0.0074 - val_loss: 0.0160
# Epoch 9/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0072 - val_loss: 0.0155
# Epoch 10/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0071 - val_loss: 0.0152
# learning rate: 0.01 done..!
# Epoch 1/10
# 550/550 [==============================] - 6s 9ms/step - loss: 0.0115 - val_loss: 0.0175
# Epoch 2/10
# 550/550 [==============================] - 4s 7ms/step - loss: 0.0075 - val_loss: 0.0149
# Epoch 3/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0067 - val_loss: 0.0138
# Epoch 4/10
# 550/550 [==============================] - 4s 8ms/step - loss: 0.0064 - val_loss: 0.0132
# Epoch 5/10
# 550/550 [==============================] - 4s 8ms/step - loss: 0.0061 - val_loss: 0.0127
# Epoch 6/10
# 550/550 [==============================] - 4s 7ms/step - loss: 0.0059 - val_loss: 0.0124
# Epoch 7/10
# 550/550 [==============================] - 4s 7ms/step - loss: 0.0057 - val_loss: 0.0122
# Epoch 8/10
# 550/550 [==============================] - 4s 8ms/step - loss: 0.0056 - val_loss: 0.0120
# Epoch 9/10
# 550/550 [==============================] - 4s 7ms/step - loss: 0.0055 - val_loss: 0.0119
# Epoch 10/10
# 550/550 [==============================] - 4s 8ms/step - loss: 0.0054 - val_loss: 0.0118
# learning rate: 0.05 done..!
# Epoch 1/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0325 - val_loss: 0.0587
# Epoch 2/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0252 - val_loss: 0.0498
# Epoch 3/10
# 550/550 [==============================] - 4s 8ms/step - loss: 0.0213 - val_loss: 0.0442
# Epoch 4/10
# 550/550 [==============================] - 4s 8ms/step - loss: 0.0189 - val_loss: 0.0403
# Epoch 5/10
# 550/550 [==============================] - 4s 7ms/step - loss: 0.0173 - val_loss: 0.0374
# Epoch 6/10
# 550/550 [==============================] - 4s 7ms/step - loss: 0.0161 - val_loss: 0.0352
# Epoch 7/10
# 550/550 [==============================] - 5s 8ms/step - loss: 0.0151 - val_loss: 0.0333
# Epoch 8/10
# 550/550 [==============================] - 4s 8ms/step - loss: 0.0143 - val_loss: 0.0318
# Epoch 9/10
# 550/550 [==============================] - 4s 7ms/step - loss: 0.0137 - val_loss: 0.0305
# Epoch 10/10
# 550/550 [==============================] - 5s 10ms/step - loss: 0.0132 - val_loss: 0.0294
# learning rate: 0.001 done..!
# Epoch 1/10
# 550/550 [==============================] - 6s 10ms/step - loss: 0.0229 - val_loss: 0.0372
# Epoch 2/10
# 550/550 [==============================] - 6s 10ms/step - loss: 0.0143 - val_loss: 0.0294
# Epoch 3/10
# 550/550 [==============================] - 6s 11ms/step - loss: 0.0119 - val_loss: 0.0256
# Epoch 4/10
# 550/550 [==============================] - 6s 11ms/step - loss: 0.0107 - val_loss: 0.0234
# Epoch 5/10
# 550/550 [==============================] - 6s 10ms/step - loss: 0.0099 - val_loss: 0.0218
# Epoch 6/10
# 550/550 [==============================] - 5s 10ms/step - loss: 0.0094 - val_loss: 0.0206
# Epoch 7/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0089 - val_loss: 0.0197
# Epoch 8/10
# 550/550 [==============================] - 6s 11ms/step - loss: 0.0086 - val_loss: 0.0190
# Epoch 9/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0084 - val_loss: 0.0184
# Epoch 10/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0081 - val_loss: 0.0179
# learning rate: 0.005 done..!
# Epoch 1/10
# 550/550 [==============================] - 6s 10ms/step - loss: 0.0379 - val_loss: 0.0727
# Epoch 2/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0364 - val_loss: 0.0706
# Epoch 3/10
# 550/550 [==============================] - 5s 10ms/step - loss: 0.0351 - val_loss: 0.0687
# Epoch 4/10
# 550/550 [==============================] - 7s 12ms/step - loss: 0.0339 - val_loss: 0.0669
# Epoch 5/10
# 550/550 [==============================] - 6s 10ms/step - loss: 0.0328 - val_loss: 0.0653
# Epoch 6/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0318 - val_loss: 0.0637
# Epoch 7/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0308 - val_loss: 0.0623
# Epoch 8/10
# 550/550 [==============================] - 6s 10ms/step - loss: 0.0300 - val_loss: 0.0610
# Epoch 9/10
# 550/550 [==============================] - 5s 10ms/step - loss: 0.0292 - val_loss: 0.0597
# Epoch 10/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0285 - val_loss: 0.0585
# learning rate: 0.0001 done..!
# Epoch 1/10
# 550/550 [==============================] - 7s 13ms/step - loss: 0.0330 - val_loss: 0.0623
# Epoch 2/10
# 550/550 [==============================] - 5s 10ms/step - loss: 0.0286 - val_loss: 0.0563
# Epoch 3/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0255 - val_loss: 0.0517
# Epoch 4/10
# 550/550 [==============================] - 4s 8ms/step - loss: 0.0232 - val_loss: 0.0482
# Epoch 5/10
# 550/550 [==============================] - 5s 8ms/step - loss: 0.0215 - val_loss: 0.0453
# Epoch 6/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0202 - val_loss: 0.0430
# Epoch 7/10
# 550/550 [==============================] - 5s 10ms/step - loss: 0.0190 - val_loss: 0.0410
# Epoch 8/10
# 550/550 [==============================] - 6s 10ms/step - loss: 0.0181 - val_loss: 0.0393
# Epoch 9/10
# 550/550 [==============================] - 4s 7ms/step - loss: 0.0174 - val_loss: 0.0379
# Epoch 10/10
# 550/550 [==============================] - 4s 8ms/step - loss: 0.0167 - val_loss: 0.0366
# learning rate: 0.0005 done..!

# %% [markdown]
# ### Running ablation studies on hyperparameters - Number of layers

# %%
train_ids, image_train_data, text_train_data, text_train_negatives = get_data('/common/home/aj780/machine_learning/CCA Data/embeddings_train1.pkl', None)

print("Train Data reading done..!")
val_ids, image_val_data, text_val_data, text_val_negatives = get_data('/common/home/aj780/machine_learning/CCA Data/embeddings_val1.pkl', None)
print("Val Data reading done..!")

test_ids, image_test_data, text_test_data, text_test_negatives = get_data('/common/home/aj780/machine_learning/CCA Data/embeddings_test1.pkl', None)
print("Test Data reading done..!")




layer_sizes = [[],[512], [512, 256], [512, 256, 128], [512, 256, 128, 64]]
i = 0
metric_data_im2recipe = pd.DataFrame(columns = ['number of layers','medR','r@1', 'r@5','r@10'], index=range(len(layer_sizes)))
metric_data_recipe2im = pd.DataFrame(columns = ['number of layers','medR','r@1', 'r@5','r@10'], index=range(len(layer_sizes)))
embeddings_type = "num_layers"
output_dir = "CCA_Final_Part2_Triplet"

embeddings_dir = output_dir + "/" + embeddings_type 


learning_rate = 0.001
n_component = 200
margin = 0.4
epochs = 10
batch_size = 512
reg_lambda = 1e-5
for ls in layer_sizes:
    
    ls.append(n_component)
    model_out_dir = embeddings_dir +  "/" + str(i+1)
    Path(model_out_dir).mkdir(parents=True, exist_ok=True)
    
    
    model = train_model(model_out_dir, image_train_data, text_train_data, text_train_negatives, 
                       image_val_data, text_val_data, text_val_negatives,
                       ls, n_component, 1024, 1024, 1024, 
                        learning_rate, margin, epochs, batch_size, reg_lambda)
    
    dataX, dataY = predict_model(model,image_test_data, text_test_data, text_test_negatives)
    medR, recall = evaluation(dataX, dataY, test_ids, True , 1000, 10)
    metric_data_im2recipe.loc[i] = [i+1, medR, recall[1], recall[5], recall[10]]
    
    medR, recall = evaluation(dataX, dataY, test_ids, False , 1000, 10)
    metric_data_recipe2im.loc[i] = [i+1, medR, recall[1], recall[5], recall[10]]
    
    
    print("number of layers: " + str(i) + " done..!")
    i+=1
    
metric_data_im2recipe.to_csv(embeddings_dir + "/numlayers_metrics_" + embeddings_type + "_im2recipe.csv", index=False)
metric_data_recipe2im.to_csv(embeddings_dir + "/numlayers_metrics_" + embeddings_type + "_recipe2im.csv", index=False)
# Out:
# Train Data reading done..!
# Val Data reading done..!
# Test Data reading done..!
# Epoch 1/10
# 550/550 [==============================] - 6s 11ms/step - loss: 0.0329 - val_loss: 0.0582
# Epoch 2/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0253 - val_loss: 0.0492
# Epoch 3/10
# 550/550 [==============================] - 4s 8ms/step - loss: 0.0213 - val_loss: 0.0436
# Epoch 4/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0189 - val_loss: 0.0397
# Epoch 5/10
# 550/550 [==============================] - 4s 8ms/step - loss: 0.0172 - val_loss: 0.0368
# Epoch 6/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.0159 - val_loss: 0.0346
# Epoch 7/10
# 550/550 [==============================] - 5s 8ms/step - loss: 0.0150 - val_loss: 0.0328
# Epoch 8/10
# 550/550 [==============================] - 4s 7ms/step - loss: 0.0142 - val_loss: 0.0313
# Epoch 9/10
# 550/550 [==============================] - 4s 8ms/step - loss: 0.0136 - val_loss: 0.0300
# Epoch 10/10
# 550/550 [==============================] - 5s 8ms/step - loss: 0.0131 - val_loss: 0.0289
# number of layers: 0 done..!
# Epoch 1/10
# 550/550 [==============================] - 10s 17ms/step - loss: 0.0841 - val_loss: 0.0593
# Epoch 2/10
# 550/550 [==============================] - 8s 15ms/step - loss: 0.